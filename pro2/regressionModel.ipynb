# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as an
import seaborn as sns

# %%
#reading the dataset
data=pd.read_csv("data.csv")
data.head()
list(data.columns[0:1])
# Out:
# ['Date']

# %%
data.head()
# Out:
#             Date  Open Price  High Price  Low Price  Close Price
# 0  21-April-2022    18150.00    18572.95   17772.90     18205.80  \
# 1  20-April-2022    18100.10    18415.00   18017.15     18313.70
# 2  19-April-2022    18470.05    18718.00   17845.60     17943.15
# 3  18-April-2022    18294.50    18684.50   18294.50     18549.85
# 4  13-April-2022    18371.20    18549.30   18248.25     18343.90
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)
# 0  18130.183442          4590           1770            83217542.0  \
# 1  18295.559071          6069           1321           111035748.0
# 2  18355.093320          2904            716            53303191.0
# 3  18511.224599          1496            586            27692792.0
# 4  18388.967826          1150            550            21147313.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low
# 0                 950.0                      20.70           800.05  \
# ...

# %%
# we need to drop date column
data.drop(columns=list(data.columns[0:1]),axis=1,inplace=True)
data.head()
# Out:
#    High Price  Low Price  Close Price           WAP  No.of Shares
# 0    18572.95   17772.90     18205.80  18130.183442          4590  \
# 1    18415.00   18017.15     18313.70  18295.559071          6069
# 2    18718.00   17845.60     17943.15  18355.093320          2904
# 3    18684.50   18294.50     18549.85  18511.224599          1496
# 4    18549.30   18248.25     18343.90  18388.967826          1150
#
#    No. of Trades  Total Turnover (Rs.)  Deliverable Quantity
# 0           1770            83217542.0                 950.0  \
# 1           1321           111035748.0                4677.0
# 2            716            53303191.0                1619.0
# 3            586            27692792.0                 557.0
# 4            550            21147313.0                 573.0
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      20.70           800.05              55.80
# 1                      77.06           397.85             213.60
# ...

# %%
import seaborn as sns
sns.pairplot(data)

# %% [markdown]
# from above we select the most relavent features

# %%
data.corr()
# Out:
#                            High Price  Low Price  Close Price       WAP
# High Price                   1.000000   0.999610     0.999793  0.999879  \
# Low Price                    0.999610   1.000000     0.999761  0.999858
# Close Price                  0.999793   0.999761     1.000000  0.999927
# WAP                          0.999879   0.999858     0.999927  1.000000
# No.of Shares                -0.073740  -0.078191    -0.075764 -0.075620
# No. of Trades                0.162156   0.150214     0.156813  0.156683
# Total Turnover (Rs.)         0.194465   0.188937     0.191751  0.191979
# Deliverable Quantity        -0.092403  -0.093886    -0.093174 -0.093045
# % Deli. Qty to Traded Qty   -0.248603  -0.245208    -0.246861 -0.247219
# Spread High-Low              0.627006   0.604996     0.616866  0.616620
# Spread Close-Open           -0.047052  -0.047372    -0.033314 -0.041972
#
#                            No.of Shares  No. of Trades  Total Turnover (Rs.)
# ...

# %% [markdown]
# we have to predict the high price of the share, from the data show above we observe that the most relavent features for this would be Low price, Close price, WAP and sperad high low i.e column

# %%
l=list(data.columns[1:4])
l.append((data.columns[9:10])[0])
X=data[l]
Y=data[data.columns[0:1]]

# %%
X.head()
# Out:
#    Low Price  Close Price           WAP  Spread High-Low
# 0   17772.90     18205.80  18130.183442           800.05
# 1   18017.15     18313.70  18295.559071           397.85
# 2   17845.60     17943.15  18355.093320           872.40
# 3   18294.50     18549.85  18511.224599           390.00
# 4   18248.25     18343.90  18388.967826           301.05

# %%
Y.head()
# Out:
#    High Price
# 0    18572.95
# 1    18415.00
# 2    18718.00
# 3    18684.50
# 4    18549.30

# %%
#train test split
X_train=X[0:1700]
X_test=X[1700:]
y_train=Y[0:1700]
y_test=Y[1700:]

# %%
print(f"the shape of xtrain is {X_train.shape}")
print(f"the shape of ytrain is {y_train.shape}")
print(f"the shape of Xtest is {X_test.shape}")
print(f"the shpae of ytest is {y_test.shape}")
X_test[0:5]
# Out:
# the shape of xtrain is (1710, 4)
# the shape of ytrain is (1710, 1)
# the shape of Xtest is (843, 4)
# the shpae of ytest is (843, 1)
# array([[-0.9064935 , -0.91344126, -0.90924536, -0.24195761],
#        [ 0.8866905 ,  0.93771669,  0.91976147,  2.21846475],
#        [-0.84686414, -0.85494993, -0.85115934, -0.18004165],
#        [ 1.37335625,  1.37430873,  1.36016835,  0.71331722],
#        [-0.29626588, -0.29769608, -0.29832127, -0.60696694]])

# %%
y_test[0:5]
# Out:
#       High Price
# 1949     4960.00
# 637     14128.25
# 2150     5261.50
# 393     16248.00
# 1023     7876.10

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
Y_hat=regression.predict(X_test)

# %%
#performance matrix
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse=mean_squared_error(y_test,Y_hat)
mae=mean_absolute_error(y_test,Y_hat)
rmse=np.sqrt(mse)
print(f"the value of means squared error is {mse}")
print(f"the value of mean absolute error is {mae}")
print(f"the value of root mean square error  is {rmse}")
# Out:
# the value of means squared error is 2.4233055750789857e-22
# the value of mean absolute error is 8.815517447433686e-12
# the value of root mean square error  is 1.5566970081165395e-11

# %%
import pickle 
pickel_out=open("multipleLinearRegression.pkl","wb")
pickle.dump(regression,pickel_out)
pickel_out.close()
